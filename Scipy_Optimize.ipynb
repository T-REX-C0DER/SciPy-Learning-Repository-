# %%
from scipy.optimize import minimize
import numpy as np

# %% [markdown]
# # Scalar Optimization

# %%
# It optimize the function with the one variable 

def f(x):
    return (x-3)**2 + 4

result  = minimiz_scalar(f)
print(result.x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 def f(x):
#       4     return (x-3)**2 + 4
# ----> 6 result  = minimize_scalar(f)
#       7 print(result.x)
#
# NameError: name 'minimize_scalar' is not defined
