# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from scipy import stats

# %%
x = np.array([1,2,3,4,5])
y = np.array([2,4,5,4,6])

result = stats.linregress(x, y)

print("Slope:", result.slope)
print("Intercept:", result.intercept)
print("R-value:", result.rvalue)
print("P-value:", result.pvalue)
# Out:
# Slope: 0.8
# Intercept: 1.7999999999999998
# R-value: 0.8528028654224418
# P-value: 0.0662756027415242

# %%
data = [10, 20, 20, 30, 40]

print("Mean:", stats.mean(data))
print("Median:", stats.median(data))
print("Mode:", stats.mode(data))

# %%
group1 = [12, 14, 15, 16, 17]
group2 = [10, 11, 13, 14, 15]

t_stat, p_val = stats.ttest_ind(group1, group2)
print("t-statistic:", t_stat)
print("p-value:", p_val)
# Out:
# t-statistic: 1.7392527130926094
# p-value: 0.12018079348826405

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]

corr, _ = stats.pearsonr(x, y)
print("Pearson Correlation:", corr)
# Out:
# Pearson Correlation: 1.0

# %%
from scipy.linalg import solve

A = np.array([[3, 2], [1, 2]])
B = np.array([5, 5])

X = solve(A, B)
print("Solution:", X)
# Out:
# Solution: [0.  2.5]

# %%
from scipy.linalg import det

A = [[1, 2], [3, 4]]
print("Determinant:", det(A))
# Out:
# Determinant: -2.0

# %%
from scipy.linalg import inv

A = [[1, 2], [3, 4]]
print("Inverse:\n", inv(A))
# Out:
# Inverse:
#  [[-2.   1. ]
#  [ 1.5 -0.5]]

# %%
import numpy as np
from scipy.linalg import lstsq

X = np.array([[1,1], [1,2], [1,3], [1,4]])
y = np.array([6,5,7,10])

coeff, res, rank, s = lstsq(X, y)
print("Intercept:", coeff[0])
print("Slope:", coeff[1])
# Out:
# Intercept: 3.4999999999999996
# Slope: 1.4000000000000004
